# %%
import pandas as pd

train_data = pd.read_csv("./data/train.csv")
test_data = pd.read_csv("./data/test.csv")

train_data
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# ...

# %%
train_data.describe()
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3263 non-null   int64
#  1   keyword   3237 non-null   object
#  2   location  2158 non-null   object
#  3   text      3263 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 102.1+ KB

# %%
# concatinate train and test data in order to fill missing values in both datasets

# %%
x_train = train_data.drop(columns=['target'] , axis=1)

# %%
x_train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text
# 0     Our Deeds are the Reason of this #earthquake M...
# 1                Forest fire near La Ronge Sask. Canada
# 2     All residents asked to 'shelter in place' are ...
# 3     13,000 people receive #wildfires evacuation or...
# 4     Just got sent this photo from Ruby #Alaska as ...
# ...                                                 ...
# 7608  Two giant cranes holding a bridge collapse int...
# 7609  @aria_ahrary @TheTawniest The out of control w...
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# ...

# %%
y = train_data['target']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7608    1
# 7609    1
# 7610    1
# 7611    1
# 7612    1
# Name: target, Length: 7613, dtype: int64

# %%
df_train_test = pd.concat([x_train , test_data] )
df_train_test
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 3258  10861     NaN      NaN
# 3259  10865     NaN      NaN
# 3260  10868     NaN      NaN
# 3261  10874     NaN      NaN
# 3262  10875     NaN      NaN
#
#                                                    text
# 0     Our Deeds are the Reason of this #earthquake M...
# 1                Forest fire near La Ronge Sask. Canada
# 2     All residents asked to 'shelter in place' are ...
# 3     13,000 people receive #wildfires evacuation or...
# 4     Just got sent this photo from Ruby #Alaska as ...
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  Storm in RI worse than last hurricane. My city...
# 3260  Green Line derailment in Chicago http://t.co/U...
# ...

# %%
df_train_test = df_train_test.drop(columns=['id'] , axis=1)
df_train_test
# Out:
#      keyword location                                               text
# 0     ablaze      USA  Our Deeds are the Reason of this #earthquake M...
# 1     ablaze      USA             Forest fire near La Ronge Sask. Canada
# 2     ablaze      USA  All residents asked to 'shelter in place' are ...
# 3     ablaze      USA  13,000 people receive #wildfires evacuation or...
# 4     ablaze      USA  Just got sent this photo from Ruby #Alaska as ...
# ...      ...      ...                                                ...
# 3258  ablaze      USA  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  ablaze      USA  Storm in RI worse than last hurricane. My city...
# 3260  ablaze      USA  Green Line derailment in Chicago http://t.co/U...
# 3261  ablaze      USA  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262  ablaze      USA  #CityofCalgary has activated its Municipal Eme...
#
# [10876 rows x 3 columns]

# %%
df_train_test['keyword'] = df_train_test['keyword'].fillna(df_train_test['keyword'].mode()[0])
df_train_test.isnull().sum()
# Out:
# keyword     0
# location    0
# text        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
df_train_test['location'].value_counts()
# Out:
# location
# USA                       3779
# New York                   109
# United States               65
# London                      58
# Canada                      42
#                           ...
# big boy Û¢ 0802             1
# Brooklyn                     1
# St.Cloud, MN                 1
# on a catwalk somewhere       1
# Brussels, Belgium            1
# Name: count, Length: 4521, dtype: int64

# %%
df_train_test['location'] = df_train_test['location'].fillna(df_train_test['location'].mode()[0])
df_train_test.isnull().sum()
# Out:
# keyword     0
# location    0
# text        0
# dtype: int64

# %%
# no empty or null values !
df_train_test
# Out:
#          id keyword location  \
# 0         1  ablaze      USA
# 1         4  ablaze      USA
# 2         5  ablaze      USA
# 3         6  ablaze      USA
# 4         7  ablaze      USA
# ...     ...     ...      ...
# 3258  10861  ablaze      USA
# 3259  10865  ablaze      USA
# 3260  10868  ablaze      USA
# 3261  10874  ablaze      USA
# 3262  10875  ablaze      USA
#
#                                                    text
# 0     Our Deeds are the Reason of this #earthquake M...
# 1                Forest fire near La Ronge Sask. Canada
# 2     All residents asked to 'shelter in place' are ...
# 3     13,000 people receive #wildfires evacuation or...
# 4     Just got sent this photo from Ruby #Alaska as ...
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  Storm in RI worse than last hurricane. My city...
# 3260  Green Line derailment in Chicago http://t.co/U...
# ...

# %%
df_train_test
# Out:
#      keyword location                                               text
# 0     ablaze      USA  Our Deeds are the Reason of this #earthquake M...
# 1     ablaze      USA             Forest fire near La Ronge Sask. Canada
# 2     ablaze      USA  All residents asked to 'shelter in place' are ...
# 3     ablaze      USA  13,000 people receive #wildfires evacuation or...
# 4     ablaze      USA  Just got sent this photo from Ruby #Alaska as ...
# ...      ...      ...                                                ...
# 3258  ablaze      USA  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  ablaze      USA  Storm in RI worse than last hurricane. My city...
# 3260  ablaze      USA  Green Line derailment in Chicago http://t.co/U...
# 3261  ablaze      USA  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262  ablaze      USA  #CityofCalgary has activated its Municipal Eme...
#
# [10876 rows x 3 columns]

# %%
text_column_train = train_data['text']
text_column_test = test_data['text']

import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
def standarlize_text(df , text_field):
    df[text_field] = df[text_field].str.replace(r"http\S+", "")
    df[text_field] = df[text_field].str.replace(r"http", "")
    df[text_field] = df[text_field].str.replace(r"@\S+", "")
    df[text_field] = df[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\_\n]", " ")
    df[text_field] = df[text_field].str.replace(r"@", "at")
    df[text_field] = df[text_field].str.lower()
    return df

clean_train = standarlize_text(train_data , 'text')
clean_test = standarlize_text(test_data , 'text')

# %%
clean_train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  our deeds are the reason of this #earthquake m...
# 1   4     NaN      NaN             forest fire near la ronge sask. canada
# 2   5     NaN      NaN  all residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  just got sent this photo from ruby #alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
tokenizer = TweetTokenizer(preserve_case=False , strip_handles=True , reduce_len=True)
clean_train['tokens'] = [tokenizer.tokenize(tweet) for tweet in clean_train['text']]
clean_test['tokens'] = [tokenizer.tokenize(tweet) for tweet in clean_test['text']]

# %%
clean_train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  our deeds are the reason of this #earthquake m...
# 1   4     NaN      NaN             forest fire near la ronge sask. canada
# 2   5     NaN      NaN  all residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  just got sent this photo from ruby #alaska as ...
#
#    target                                             tokens
# 0       1  [our, deeds, are, the, reason, of, this, #eart...
# 1       1   [forest, fire, near, la, ronge, sask, ., canada]
# 2       1  [all, residents, asked, to, ', shelter, in, pl...
# 3       1  [13,000, people, receive, #wildfires, evacuati...
# 4       1  [just, got, sent, this, photo, from, ruby, #al...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def cv(data):
    count_vectorizer = CountVectorizer()

    emb = count_vectorizer.fit_transform(data)

    return emb, count_vectorizer

list_corpus = clean_train["text"].tolist()
list_labels = clean_train["target"].tolist()

X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.2, random_state=40)

X_train_counts, count_vectorizer = cv(X_train)
X_test_counts = count_vectorizer.transform(X_test)

# %%
X_train_counts
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 85839 stored elements and shape (6090, 18648)>

# %%
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt


def plot_LSA(test_data, test_labels, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue','blue']
        if plot:
            plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            red_patch = mpatches.Patch(color='orange', label='Not Relevant')
            green_patch = mpatches.Patch(color='blue', label='Relevant')
            plt.legend(handles=[red_patch, green_patch], prop={'size': 30})


fig = plt.figure(figsize=(16, 16))          
plot_LSA(X_train_counts, y_train)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(X_train_counts, y_train)

y_predicted_counts = clf.predict(X_test_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       4 clf.fit(X_train_counts, y_train)
#       6 y_predicted_counts = clf.predict(X_test_counts)
# ----> 8 accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
#       9 print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
#
# NameError: name 'get_metrics' is not defined

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
def get_metrics(y_test, y_predicted):  
    # true positives / (true positives+false positives)
    precision = precision_score(y_test, y_predicted, pos_label=None,
                                    average='weighted')             
    # true positives / (true positives + false negatives)
    recall = recall_score(y_test, y_predicted, pos_label=None,
                              average='weighted')
    
    # harmonic mean of precision and recall
    f1 = f1_score(y_test, y_predicted, pos_label=None, average='weighted')
    
    # true positives + true negatives/ total
    accuracy = accuracy_score(y_test, y_predicted)
    return accuracy, precision, recall, f1
  

accuracy, precision, recall, f1 = get_metrics(y_test, y_predicted_counts)
print("accuracy = %.3f, precision = %.3f, recall = %.3f, f1 = %.3f" % (accuracy, precision, recall, f1))
# Out:
# accuracy = 0.791, precision = 0.807, recall = 0.791, f1 = 0.783

# %%
X_test_fin = clean_test["text"].tolist()
X_test_coun = count_vectorizer.transform(X_test_fin)
predictions = clf.predict(X_test_coun)
print(predictions)
# Out:
# [0 0 1 ... 1 1 0]

# %%
submission = pd.DataFrame()
submission["id"] = clean_test["id"]
submission["target"] = predictions
submission.to_csv("submission.csv", index = False)
submission.head(n = 10)
# Out:
#    id  target
# 0   0       0
# 1   2       0
# 2   3       1
# 3   9       0
# 4  11       1
# 5  12       0
# 6  21       0
# 7  22       0
# 8  27       0
# 9  29       0
